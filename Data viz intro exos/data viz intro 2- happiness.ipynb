# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
df = pd.read_csv('world-happiness-report-2021.csv')
df_all = pd.read_csv('world-happiness-report.csv')
df_all.head(15)
#dataO = pd.read_csv("Data/Top 100 most Streamed.csv")
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0   Afghanistan  2008        3.724               7.370           0.451
# 1   Afghanistan  2009        4.402               7.540           0.552
# 2   Afghanistan  2010        4.758               7.647           0.539
# 3   Afghanistan  2011        3.832               7.620           0.521
# 4   Afghanistan  2012        3.783               7.705           0.521
# 5   Afghanistan  2013        3.572               7.725           0.484
# 6   Afghanistan  2014        3.131               7.718           0.526
# 7   Afghanistan  2015        3.983               7.702           0.529
# 8   Afghanistan  2016        4.220               7.697           0.559
# 9   Afghanistan  2017        2.662               7.697           0.491
# 10  Afghanistan  2018        2.694               7.692           0.508
# 11  Afghanistan  2019        2.375               7.697           0.420
# ...

# %%
correlations = df_all.corr()
correlations
sns.heatmap(correlations, cmap='Blues').set_title("Correlations")
# Out:
# Text(0.5, 1.0, 'Correlations')

# %%
df_all.hist()
plt.show()

# %%
df_all["Country name"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Estonia', 'Ethiopia', 'Finland', 'France', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'Hong Kong S.A.R. of China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
# ...

# %%
df_all.sort_values("Life Ladder", ascending=False)
# Out:
#                   Country name  year  Life Ladder  Log GDP per capita  \
# 449                    Denmark  2005        8.019              10.851
# 451                    Denmark  2008        7.971              10.880
# 563                    Finland  2020        7.889              10.750
# 561                    Finland  2018        7.858              10.783
# 450                    Denmark  2007        7.834              10.891
# ...                        ...   ...          ...                 ...
# 1947                  Zimbabwe  2019        2.694               7.950
# 311   Central African Republic  2016        2.693               6.785
# 1667                     Syria  2013        2.688               8.396
# 9                  Afghanistan  2017        2.662               7.697
# 11                 Afghanistan  2019        2.375               7.697
#
#       Social support  Healthy life expectancy at birth  \
# 449            0.972                             69.60
# ...

# %%
null_data = df_all[df_all.isnull().any(axis=1)]
null_data
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 25        Algeria  2010        5.464               9.287             NaN
# 28        Algeria  2014        6.355               9.335           0.818
# 29        Algeria  2016        5.341               9.362           0.749
# 66      Australia  2005        7.341              10.659           0.968
# 110       Bahrain  2012        5.027              10.716           0.911
# ...           ...   ...          ...                 ...             ...
# 1908        Yemen  2007        4.477               8.214           0.825
# 1916        Yemen  2016        3.826               7.715           0.775
# 1917        Yemen  2017        3.254               7.578           0.790
# 1918        Yemen  2018        3.058                 NaN           0.789
# 1919        Yemen  2019        4.197                 NaN           0.870
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
not_null = df_all[df_all.notnull().all(axis=1)]
not_null
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
happiness_mean = df_all.groupby(["Country name", "year"]).mean()
happiness_mean
# Out:
#                    Life Ladder  Log GDP per capita  Social support  \
# Country name year
# Afghanistan  2008        3.724               7.370           0.451
#              2009        4.402               7.540           0.552
#              2010        4.758               7.647           0.539
#              2011        3.832               7.620           0.521
#              2012        3.783               7.705           0.521
# ...                        ...                 ...             ...
# Zimbabwe     2016        3.735               7.984           0.768
#              2017        3.638               8.016           0.754
#              2018        3.616               8.049           0.775
#              2019        2.694               7.950           0.759
#              2020        3.160               7.829           0.717
#
#                    Healthy life expectancy at birth  \
# Country name year
# Afghanistan  2008                             50.80
# ...

# %%
rel = sns.relplot(data=df_all, x='Log GDP per capita', y='Generosity', hue='Life Ladder')
rel.fig.suptitle("GDP vs Generosity", x=0.6, y=1.1, fontsize=17)
# Out:
# Text(0.6, 1.1, 'GDP vs Generosity')

# %%
rel = sns.relplot(data=df_all, x='Log GDP per capita', y='Life Ladder')
rel.fig.suptitle("GDP vs Life ladder", x=0.6, y=1.1, fontsize=17)
# Out:
# Text(0.6, 1.1, 'GDP vs Life ladder')

# %%
rel = sns.relplot(data=df_all, x='Social support', y='Freedom to make life choices', hue='Life Ladder')
rel.fig.suptitle("Support vs Freedom", x=0.6, y=1.1, fontsize=17)
# Out:
# Text(0.6, 1.1, 'Support vs Freedom')

# %%
missing = df_all["Country name"][df_all.isnull().any(axis=1)].unique()
# Out:
# array(['Algeria', 'Australia', 'Bahrain', 'Bangladesh', 'Belarus',
#        'Belgium', 'Brazil', 'Cambodia', 'Canada', 'China',
#        'Congo (Brazzaville)', 'Cuba', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Egypt', 'Ethiopia', 'France', 'Germany',
#        'Greece', 'Hong Kong S.A.R. of China', 'Hungary', 'Iceland',
#        'India', 'Iran', 'Iraq', 'Israel', 'Italy', 'Japan', 'Jordan',
#        'Kosovo', 'Kuwait', 'Laos', 'Lebanon', 'Libya', 'Madagascar',
#        'Maldives', 'Malta', 'Mexico', 'Morocco', 'Myanmar', 'Nepal',
#        'Netherlands', 'North Cyprus', 'Oman', 'Pakistan',
#        'Palestinian Territories', 'Philippines', 'Poland', 'Qatar',
#        'Romania', 'Rwanda', 'Saudi Arabia', 'Singapore', 'Somalia',
#        'Somaliland region', 'South Africa', 'South Korea', 'South Sudan',
#        'Spain', 'Sweden', 'Taiwan Province of China', 'Tajikistan',
#        'Tunisia', 'Turkey', 'Turkmenistan', 'United Arab Emirates',
# ...

# %%
test = df_all.groupby("Country name").mean()
test
null_test = test[test.isnull().any(axis=1)]
null_test
# Out:
#                                   year  Life Ladder  Log GDP per capita  \
# Country name
# China                      2013.000000     5.047933            9.280267
# Cuba                       2006.000000     5.418000                 NaN
# Hong Kong S.A.R. of China  2012.909091     5.447091           10.888700
# Kosovo                     2013.500000     5.672571            9.127077
# Maldives                   2018.000000     5.198000            9.826000
# North Cyprus               2015.285714     5.651571                 NaN
# Oman                       2011.000000     6.853000           10.382000
# Somalia                    2015.000000     5.183333                 NaN
# Somaliland region          2010.500000     4.909000                 NaN
# South Sudan                2015.500000     3.402000                 NaN
# Turkmenistan               2014.400000     5.600500            9.401900
#
#                            Social support  Healthy life expectancy at birth  \
# ...

# %%
missing = df_all["Country name"][df_all.isnull().any(axis=1)].unique()

#backfill apply
filtre = df_all["Country name"] == "Brazil"
test = df_all[filtre].fillna(method='bfill', axis=0) 
#test2 = df_all[filtre].apply(np.mean, axis=1)

test
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 218       Brazil  2005        6.637               9.438           0.883
# 219       Brazil  2007        6.321               9.515           0.886
# 220       Brazil  2008        6.691               9.555           0.878
# 221       Brazil  2009        7.001               9.544           0.913
# 222       Brazil  2010        6.837               9.607           0.906
# 223       Brazil  2011        7.038               9.637           0.916
# 224       Brazil  2012        6.660               9.647           0.890
# 225       Brazil  2013        7.140               9.668           0.910
# 226       Brazil  2014        6.981               9.664           0.898
# 227       Brazil  2015        6.547               9.620           0.907
# 228       Brazil  2016        6.375               9.578           0.912
# 229       Brazil  2017        6.333               9.583           0.905
# ...

# %%
null_data = df_all.isna().sum()
null_data
null_data.count()
# Out:
# 11

# %%
pays_list =  df_all["Country name"].unique()
cols = df_all.columns
new_data = pd.DataFrame(columns=cols)

for pays in pays_list:
    data_pay=df_all[df_all['Country name']==pays].fillna(method='bfill', axis=0).fillna(method='ffill', axis=0)
    new_data.dropna(axis=0, how='any', inplace=True)
    new_data = new_data.append(data_pay)
            

#new_data.drop_duplicates(keep="first", inplace=True)
new_data[new_data['Country name']=='Argentina']
#new_data.info()
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 37    Argentina  2006        6.313               9.942           0.938
# 38    Argentina  2007        6.073              10.018           0.862
# 39    Argentina  2008        5.961              10.048           0.892
# 40    Argentina  2009        6.424               9.977           0.919
# 41    Argentina  2010        6.441              10.066           0.927
# 42    Argentina  2011        6.776              10.112           0.889
# 43    Argentina  2012        6.468              10.091           0.902
# 44    Argentina  2013        6.582              10.103           0.910
# 45    Argentina  2014        6.671              10.067           0.918
# 46    Argentina  2015        6.697              10.083           0.926
# 47    Argentina  2016        6.427              10.051           0.883
# 48    Argentina  2017        6.039              10.067           0.907
# ...
